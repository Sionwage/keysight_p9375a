# %% [markdown]
# # Keysight P9375A Testing

# %% [markdown]
# ## Instructions

# %% [markdown]
# ## Environment

# %%
import os

from keysight_p9375a import KeysightP9375A

os.add_dll_directory(r"C:\Program Files (x86)\Keysight\IO Libraries Suite\bin")
os.add_dll_directory(r"C:\Program Files\Keysight\IO Libraries Suite\bin")

rm = pyvisa.ResourceManager()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 from keysight_p9375a import KeysightP9375A
#       5 os.add_dll_directory(r"C:\Program Files (x86)\Keysight\IO Libraries Suite\bin")
#       6 os.add_dll_directory(r"C:\Program Files\Keysight\IO Libraries Suite\bin")
#
# File ~\Python Git\keysight_p9375a\keysight_p9375a.py:27
#       1 #
#       2 # This file is part of the PyMeasure package.
#       3 #
#    (...)     22 # THE SOFTWARE.
#      23 #
#      25 import logging
# ---> 27 from pymeasure.instruments import Channel, Instrument
#      28 from pymeasure.instruments.generic_types import SCPIMixin
#      29 from pymeasure.instruments.validators import strict_range, strict_discrete_set, strict_discrete_range
#
# ModuleNotFoundError: No module named 'pymeasure'

# %%
# create vna object using hislip
vna = KeysightP9375A(rm.open_resource("TCPIP0::127.0.0.1::hislip0::INSTR"))
